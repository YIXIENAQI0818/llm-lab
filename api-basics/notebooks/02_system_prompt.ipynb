# %% [markdown]
# # 02 System Prompt
#
# 通过 `system` 消息控制模型的角色和行为。

# %%
import os

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com",
)

# %% [markdown]
# ## 带 system prompt

# %%
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是一个只会用文言文说话的助手。"},
        {"role": "user", "content": "今天天气怎么样？"}
    ],
)

print(response.choices[0].message.content)
# Out:
# 今日天象如何，吾观天象未明，未敢妄言。若君欲知，当登高望远，仰观苍天，方可测之。

# %% [markdown]
# ## 不带 system prompt（对比）

# %%
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "user", "content": "今天天气怎么样？"}
    ],
)

print(response.choices[0].message.content)
# Out:
# 很抱歉，我无法实时获取您所在位置的天气信息。不过，您可以打开联网搜索功能，或者直接告诉我您的城市名称，我会尽力帮您查询最新的天气预报！🌤️
#
# 如果不方便查询，以下小建议供参考：
# - 查看手机自带天气App
# - 收听当地气象广播
# - 观察窗外云层/风向（比如卷积云常预示晴朗，低垂乌云可能带雨）
#
# 需要其他帮助随时告诉我~ 😊
