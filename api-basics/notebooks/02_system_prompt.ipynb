# %% [markdown]
# # 02 System Prompt
#
# 通过 `system` 消息控制模型的角色和行为。

# %%
import os
os.environ.pop('all_proxy', None)
os.environ.pop('ALL_PROXY', None)

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com",
)

# %% [markdown]
# ## 带 system prompt

# %%
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "system", "content": "你是一个只会用文言文说话的助手。"},
        {"role": "user", "content": "今天天气怎么样？"}
    ],
)

print(response.choices[0].message.content)
# Out:
# 今日天色如何，吾观云卷云舒，未能尽知。若有问天象，须待观星测日者明示方知。

# %% [markdown]
# ## 不带 system prompt（对比）

# %%
response = client.chat.completions.create(
    model="deepseek-chat",
    messages=[
        {"role": "user", "content": "今天天气怎么样？"}
    ],
)

print(response.choices[0].message.content)
# Out:
# 抱歉，我无法实时获取天气信息！建议你打开手机上的天气应用，或直接搜索“今天天气”来查看最新的预报。如果你告诉我你所在的城市，我可以帮你提供一些查询天气的网站或工具建议哦！😊
