# %% [markdown]
# # 03 多轮对话
#
# 通过维护 messages 列表实现对话历史，让模型记住上下文。

# %%
import os

from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

client = OpenAI(
    api_key=os.getenv("DEEPSEEK_API_KEY"),
    base_url="https://api.deepseek.com",
)

# %% [markdown]
# ## 构建多轮对话

# %%
messages = [
    {"role": "system", "content": "你是一个简洁、乐于助人的助手。"},
]

turns = [
    "我叫小明，今年 22 岁。",
    "我喜欢吃什么？",
    "我刚才说我喜欢披萨和火锅。",
    "那你还记得我叫什么名字吗？"
]

for user_msg in turns:
    messages.append({"role": "user", "content": user_msg})
    response = client.chat.completions.create(
        model="deepseek-chat",
        messages=messages,
    )
    assistant_msg = response.choices[0].message.content
    messages.append({"role": "assistant", "content": assistant_msg})
    print(f"User: {user_msg}")
    print(f"Assistant: {assistant_msg}")
    print("---")
# Out:
# User: 我叫小明，今年 22 岁。
# Assistant: 你好，小明！22 岁是个充满可能性的年纪，有什么需要帮忙的吗？
# ---
# User: 我喜欢吃什么？
# Assistant: 我暂时还不知道你的口味偏好呢。要不你告诉我几样你喜欢的食物，我帮你想想相关的推荐？
# ---
# User: 我刚才说我喜欢披萨和火锅。
# Assistant: 好的，记住了！你喜欢披萨和火锅。有需要推荐的口味或店铺，随时可以问我。
# ---
# User: 那你还记得我叫什么名字吗？
# Assistant: 当然记得，你叫小明！
# ---

# %% [markdown]
# ## 最终 messages 列表

# %%
for i, msg in enumerate(messages):
    role = msg["role"]
    content = msg["content"][:80]
    suffix = "..." if len(msg["content"]) > 80 else ""
    print(f"[{i}] {role}: {content}{suffix}")
# Out:
# [0] system: 你是一个简洁、乐于助人的助手。
# [1] user: 我叫小明，今年 22 岁。
# [2] assistant: 你好，小明！22 岁是个充满可能性的年纪，有什么需要帮忙的吗？
# [3] user: 我喜欢吃什么？
# [4] assistant: 我暂时还不知道你的口味偏好呢。要不你告诉我几样你喜欢的食物，我帮你想想相关的推荐？
# [5] user: 我刚才说我喜欢披萨和火锅。
# [6] assistant: 好的，记住了！你喜欢披萨和火锅。有需要推荐的口味或店铺，随时可以问我。
# [7] user: 那你还记得我叫什么名字吗？
# [8] assistant: 当然记得，你叫小明！
